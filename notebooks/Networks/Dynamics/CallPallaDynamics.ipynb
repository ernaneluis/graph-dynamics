# %%
import sys
import os
import networkx as nx
import numpy as np
import pandas as pd
from scipy.stats import binom

from matplotlib import pyplot as plt
sys.path.append("../../../")
# %matplotlib inline

# %%
#os.listdir("../../../")

# %%
from graph_dynamics.dynamics import PittWalker
from graph_dynamics.random_measures import process
from graph_dynamics.networks.datatypes import CaronFoxGraphs

# %%
tau = 1.
alpha = 20.
sigma = alpha
process_identifier_string = "GammaProcess"

G = process.GammaProcess(process_identifier_string,
                         sigma,
                         tau,
                         alpha,
                         K=100)
G.plotProcess()
graph_identifier = "CaronFoxTest"
CaronFoxGraph = CaronFoxGraphs(graph_identifier,G)
nx.draw(CaronFoxGraph.network)
plt.show()

# %%
#Dynamics 
phi = 1.
rho = 1.

Palla = PittWalker.PallaDynamics(phi,rho,CaronFoxGraph)
#C_TimeSeries = Palla.generateHiddenPath(10)
Networks_TimeSeries = Palla.generateNetworkPaths(10)
# Out:
# {15.790242440600373: 1.0, 11.07144715255134: 1.0, 3.3030387224535551: 1.0, 8.997655900764288: 1.0, 13.727944668748968: 1.0, 19.457978396633148: 1.0, 12.237171943391427: 1.0, 5.0882802703170764: 5.0, 13.269757025237777: 1.0, 13.165033097388557: 1.0}
# Time Iteration 1
# Number of old tables 29.0
# Number of current nodes 101
# Time Iteration 2
# Number of old tables 72.0
# Number of current nodes 131
# Time Iteration 3
# Number of old tables 91.0
# Number of current nodes 122
# Time Iteration 4
# Number of old tables 142
# Number of current nodes 171
# Time Iteration 5
# Number of old tables 222.0
# Number of current nodes 159
# Time Iteration 6
# Number of old tables 249.0
# Number of current nodes 172
# Time Iteration 7
# Number of old tables 381.0
# Number of current nodes 202
# Time Iteration 8
# Number of old tables 568.0
# Number of current nodes 206
# Time Iteration 9
# Number of old tables 736
# Number of current nodes 214

# %%
len(Networks_TimeSeries)
# Out:
# 10

# %%
def pandasDataFrameNxList(graphList,functionsDictionary):
    for graph in graphList:
        for function in
        nx.number_of_edges(Networks_TimeSeries[-1])
# Out:
# 5661

# %%
{"NumberOfEdges":nx.number_of_edges,"NumberOfNodes":nx.number_of_nodes}
# Out:
# {'NumberOfEdges': <function networkx.classes.function.number_of_edges>}
