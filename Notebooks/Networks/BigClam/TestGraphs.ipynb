# %%
import os
import networkx as nx
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
easy_graph = nx.barabasi_albert_graph(5000,m=3)

# %%
"""
easy_graph.add_edge(1,2)
easy_graph.add_edge(1,3)
easy_graph.add_edge(1,4)
easy_graph.add_edge(1,5)
easy_graph.add_edge(1,6)
easy_graph.add_edge(1,7)
easy_graph.add_edge(10,23)
"""
# Out:
# '\neasy_graph.add_edge(1,2)\neasy_graph.add_edge(1,3)\neasy_graph.add_edge(1,4)\neasy_graph.add_edge(1,5)\neasy_graph.add_edge(1,6)\neasy_graph.add_edge(1,7)\neasy_graph.add_edge(10,23)\n'

# %%
nx.draw(easy_graph)

# %%
os.listdir("../../../data/bigclam/")
# Out:
# ['easy_bigclam_0_f_matrix.txt',
#  'easy_gGD_0_.gd',
#  'easy_bigclam_0.txt',
#  'bitcoin']

# %%
nx.write_edgelist(easy_graph,"../../../data/bigclam/easy_gGD_0_.gd")

# %%
os.listdir("../../../data/bigclam/")
# Out:
# ['easy_bigclam_0_f_matrix.txt',
#  'easy_gGD_0_.gd',
#  'easy_bigclam_0.txt',
#  'bitcoin']

# %%
A = np.loadtxt('../../../data/bigclam/easy_bigclam_0_f_matrix.txt')

# %%
A, B , C  = plt.hist(A,range=(1,5),bins=50)

# %%
plt.plot(B[:-1],A,"ro")
plt.loglog()
# Out:
# /home/cesar/tensorflow/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:3193: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))
# []
